# %% [markdown]
# # Example of GraphRag
# In this example we will be building KnowledgeGraph of Keras-nlp README.md

# %% [markdown]
# First clone the Project-Explainer to use GraphRag to build KnowledgeGraph

# %%
# !git clone https://github.com/debrupf2946/Project-Explainer.git
# Out:
# Cloning into 'Project-Explainer'...
# remote: Enumerating objects: 154, done.
# remote: Counting objects: 100% (55/55), done.
# remote: Compressing objects: 100% (35/35), done.
# remote: Total 154 (delta 27), reused 32 (delta 19), pack-reused 99
# Receiving objects: 100% (154/154), 1.40 MiB | 1.88 MiB/s, done.
# Resolving deltas: 100% (63/63), done.

# %% [markdown]
# Setup the project by installing requirements.txt

# %%
# %pip install -r /content/Project-Explainer/GraphRag/requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.0/756.0 kB 12.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 496.7/496.7 kB 3.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 51.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.4/15.4 MB 62.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 24.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 63.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 1.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.8/130.8 kB 11.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 328.3/328.3 kB 19.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 41.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 853.2/853.2 kB 51.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 59.3 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## LLM SETUP
# For setting ollama we use colab-xterm to get terminal acces,for free version of colab we donot get terminal access

# %%
# !pip install colab-xterm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.6/115.6 kB 3.8 MB/s eta 0:00:00
# ...

# %%
# %load_ext colabxterm

# %% [markdown]
# use following shell commands to install ollama and serve
#
#
# ```
# curl -fsSL https://ollama.com/install.sh | sh
# ```
#
#
# ```
# ollama serve
# ```

# %%
# %xterm
# Out:
# Launching Xterm...

# %% [markdown]
# install llama3 or any other model supported by ollama
#
#
# ```
# ollama run llama3
# ```

# %%
# %xterm
# Out:
# Launching Xterm...

# %%
# ,required_exts= [".md"],recursive=True

# %% [markdown]
# ## Building the KnowledgeGraph
# Import all the nessecory functions from GraphRag to build the graph

# %%
from Project_Explainer.GraphRag.tools import load_directory,initialize_llm

# %%
from Project_Explainer.GraphRag.knowledgeGraph import build_graph,save_index

# %% [markdown]
# ### Initialization
# Initialize llm with default settings that is llama3 with *chunk size=512*

# %%
initialize_llm()
# Out:
# llama3 initialized succesfully!

# %% [markdown]
# ### Data Loading
# Provide the path to the directory containing the documents that is keras-nlp.md which loads the file,chunks it and create a llama-index *Document* object

# %%
documents=load_directory("/content/drive/MyDrive/templates")
# Out:
# 289Documents loaded succesfully!

# %% [markdown]
# ### GraphCreation
# now we build KnowledgeGraph index by passing the douments and setting *max_triplets_per_chunk=5* and leaving other settings to default(*embeddings=microsoft/codebert-base*).
#
# Index creation takes time!

# %%
index=build_graph(documents,max_triplets_per_chunk=5)
# Out:
# WARNING:sentence_transformers.SentenceTransformer:No sentence-transformers model found with name microsoft/codebert-base. Creating a new one with mean pooling.
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/498 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/499M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/150 [00:00<?, ?B/s]
# KG built succesfully!
# Graph_visualization.html

# %% [markdown]
# ### Saving Index
# we save the index built by serealizing with pickle so that we can query on this graph later and we don't have to build KnowledgeGraphs repeatedly

# %%
save_index(index)
# Out:
# Index saved succesfully!

# %% [markdown]
# ### Visulaisation
# build_graph() method automatically creates and Graph_visualization.html file that gives a visualisation of the graph

# %%
from IPython.display import display, HTML

# Load and display the HTML file
with open('/content/Graph_visualization.html', 'r') as file:
    html_content = file.read()

display(HTML(html_content))
# Out:
# <html>
#     <head>
#         <meta charset="utf-8">
#
#             <script>function neighbourhoodHighlight(params) {
#   // console.log("in nieghbourhoodhighlight");
#   allNodes = nodes.get({ returnType: "Object" });
#   // originalNodes = JSON.parse(JSON.stringify(allNodes));
#   // if something is selected:
#   if (params.nodes.length > 0) {
#     highlightActive = true;
#     var i, j;
#     var selectedNode = params.nodes[0];
#     var degrees = 2;
#
#     // mark all nodes as hard to read.
#     for (let nodeId in allNodes) {
#       // nodeColors[nodeId] = allNodes[nodeId].color;
#       allNodes[nodeId].color = "rgba(200,200,200,0.5)";
#       if (allNodes[nodeId].hiddenLabel === undefined) {
#         allNodes[nodeId].hiddenLabel = allNodes[nodeId].label;
#         allNodes[nodeId].label = undefined;
#       }
#     }
#     var connectedNodes = network.getConnectedNodes(selectedNode);
#     var allConnectedNodes = [];
#
#     // get the second degree nodes
# ...

# %%
query_engine = index.as_query_engine(
    include_text=True,
    response_mode="tree_summarize",
    embedding_mode="hybrid",
    similarity_top_k=5,
)

# %%
response = query_engine.query(
    "application of kerasnlp",
)
# Out:
# WARNING:llama_index.core.indices.knowledge_graph.retrievers:Index was not constructed with embeddings, skipping embedding usage...

# %%
from IPython.display import Markdown, display
display(Markdown(f"{response}"))

# %% [markdown]
# KerasNLP is a Python library that provides a simple and easy-to-use interface for applying Natural Language Processing (NLP) techniques to text data. It is built on top of the popular deep learning library Keras, which is itself an API implemented in Python, based on the TensorFlow or Theano frameworks.
#
# The application of KerasNLP can be seen in various areas such as:
#
# 1. Sentiment Analysis: KerasNLP can be used to analyze text data and determine whether it's positive, negative, or neutral.
# 2. Text Classification: It can classify text into different categories like spam/not-spam emails, or news articles into different topics.
# Language Modeling: KerasNLP can predict the next word in a sequence of words based on the context.
# 3. Named Entity Recognition (NER): It can identify named entities such as people, places, and organizations from unstructured text data.
# Overall, the application of KerasNLP is in areas where there's a need to analyze or process large amounts of text data using deep learning techniques.
